# %%
import PIL.Image as pilimg
import numpy as np

a1 = pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=0,m=0.jpg')
a2=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=0,m=1.jpg')
a3=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=0,m=2.jpg')
a4=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=0,m=3.jpg')
a5=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=0,m=4.jpg')
a6=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=0,m=5.jpg')
a7=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=1,m=0.jpg')
a8=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=1,m=1.jpg')
a9=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=1,m=2.jpg')
a10=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=1,m=3.jpg')
a11=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=1,m=4.jpg')
a12=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=1,m=5.jpg')
a13=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=2,m=0.jpg')
a14=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=2,m=1.jpg')
a15=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=2,m=2.jpg')
a16=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=2,m=3.jpg')
a17=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=2,m=4.jpg')
a18=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=2,m=5.jpg')
a19=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=3,m=0.jpg')
a20=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=3,m=1.jpg')
a21=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=3,m=2.jpg')
a22=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=3,m=3.jpg')
a23=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=3,m=4.jpg')
a24=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=3,m=5.jpg')
a25=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=4,m=0.jpg')
a26=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=4,m=1.jpg')
a27=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=4,m=2.jpg')
a28=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=4,m=3.jpg')
a29=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=4,m=4.jpg')
a30=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=4,m=5.jpg')
a31=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=5,m=0.jpg')
a32=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=5,m=1.jpg')
a33=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=5,m=2.jpg')
a34=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=5,m=3.jpg')
a35=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=5,m=4.jpg')
a36=  pilimg.open(r'C:/Users/khl36/Hackathon/imgdata/LG/n=5,m=5.jpg')





def makearr(x):
    ar = np.array(x)
    ar = ar[1:,1:]
    return ar


def threshold(array):
    
    #16*16 data
    data = np.zeros([16,16])
    
    #thtreshold
    for i in range(16):
        for j in range(16):
            
            
            if array[i,j]>=128:
                data[i,j] = 0
            
            else:
                data[i,j]=1
                
    return data

def threshold2(array):
    
    #16*16 data
    data = np.zeros([16,16])
    
    #thtreshold
    for i in range(16):
        for j in range(15):
            
            data[i,0]=1
            
            if array[i,j]>=128:
                data[i,j+1] = 0
            
            else:
                data[i,j+1]=1
    
                
    return data


output = []
output.append(threshold2(makearr(a1)))
output.append(threshold2(makearr(a2)))
output.append(threshold2(makearr(a3)))
output.append(threshold2(makearr(a4)))
output.append(threshold2(makearr(a5)))
output.append(threshold2(makearr(a6)))
output.append(threshold2(makearr(a7)))
output.append(threshold2(makearr(a8)))
output.append(threshold2(makearr(a9)))
output.append(threshold2(makearr(a10)))
output.append(threshold2(makearr(a11)))
output.append(threshold2(makearr(a12)))
output.append(threshold2(makearr(a13)))
output.append(threshold2(makearr(a14)))
output.append(threshold2(makearr(a15)))
output.append(threshold2(makearr(a16)))
output.append(threshold2(makearr(a17)))
output.append(threshold2(makearr(a18)))
output.append(threshold2(makearr(a19)))
output.append(threshold2(makearr(a20)))
output.append(threshold2(makearr(a21)))
output.append(threshold2(makearr(a22)))
output.append(threshold2(makearr(a23)))
output.append(threshold2(makearr(a24)))
output.append(threshold2(makearr(a25)))
output.append(threshold2(makearr(a26)))
output.append(threshold2(makearr(a27)))
output.append(threshold2(makearr(a28)))
output.append(threshold2(makearr(a29)))
output.append(threshold2(makearr(a30)))
output.append(threshold2(makearr(a31)))
output.append(threshold2(makearr(a32)))
output.append(threshold2(makearr(a33)))
output.append(threshold2(makearr(a34)))
output.append(threshold2(makearr(a35)))
output.append(threshold2(makearr(a36)))

data = np.stack(output,axis=0)
np.savez("LGp.npz",data = data)
